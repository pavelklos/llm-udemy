# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Rhen email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# Starting diagnostics at 2024-12-02 11:23:25
#
# ===== System Information =====
# Operating System: Windows
# Windows Release: 10
# Windows Version: 10.0.19045
# Architecture: ('64bit', 'WindowsPE')
# Machine: AMD64
# Processor: Intel64 Family 6 Model 142 Stepping 9, GenuineIntel
# Total RAM: 15.89 GB
# Available RAM: 7.13 GB
# Free Disk Space: 6.38 GB
#
# ===== File System Information =====
# Current Directory: C:\Users\Pavel\projects\llm-udemy
# Write permission: OK
#
# Files in Current Directory:
#  - .env
#  - .git
#  - .gitignore
#  - .ipynb_checkpoints
#  - LICENSE
#  - README.md
#  - SETUP-PC.md
#  - SETUP-PC.pdf
#  - SETUP-mac.md
#  - SETUP-mac.pdf
#  - __pycache__
#  - business.jpg
#  - diagnostics.ipynb
#  - diagnostics.py
#  - environment.yml
#  - important.jpg
#  - report.txt
#  - requirements.txt
#  - resources.jpg
#  - voyage.jpg
#  - week1
#
# ===== Git Repository Information =====
# Git Repository Root: C:/Users/Pavel/projects/llm-udemy
# Current Commit: bed86277e7c5c061f7b323e4f79d1ee4d7472f45
# Remote Origin: https://github.com/pavelklos/llm-udemy.git
#
# ===== Environment File Check =====
# .env file exists at: C:/Users/Pavel/projects/llm-udemy\.env
# OPENAI_API_KEY found in .env file
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: C:\Users\Pavel\miniconda3\envs\llms
# Environment Name: llms
# Conda Version: conda 24.3.0
#
# Python Environment:
# Python Version: 3.11.10 | packaged by conda-forge | (main, Oct 16 2024, 01:17:14) [MSC v.1941 64 bit (AMD64)]
# Python Executable: C:\Users\Pavel\miniconda3\envs\llms\python.exe
#
# Required Package Versions:
# openai: 1.55.3
# python-dotenv: 1.0.1
# requests: 2.32.3
# gradio: 5.7.1
# transformers: 4.46.3
#
# ===== Virtualenv Check =====
# No active virtualenv detected
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.4.0 22 Oct 2024
# ✓ Connected to https://www.google.com
#   Response time: 0.21s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 193.42 Mbps
# Upload speed: 121.68 Mbps
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - C:\Users\Pavel\miniconda3\envs\llms\python311.zip
#  - C:\Users\Pavel\miniconda3\envs\llms\DLLs
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib
#  - C:\Users\Pavel\miniconda3\envs\llms
#  -
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib\site-packages
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib\site-packages\win32
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib\site-packages\win32\lib
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib\site-packages\Pythonwin
#  - C:\Users\Pavel\miniconda3\envs\llms\Lib\site-packages\setuptools\_vendor
# OPENAI_API_KEY is set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: C:\Users\Pavel\AppData\Local\Temp
#
# ✅ All diagnostics passed successfully!
#
#
# Completed diagnostics at 2024-12-02 11:23:49
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
